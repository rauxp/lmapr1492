# %%
from pymatgen.symmetry.analyzer import SpacegroupAnalyzer
from pymatgen.ext.matproj import MPRester
from pymatgen.io.cif import CifWriter
from pymatgen.analysis.diffraction.xrd import XRDCalculator
from matplotlib import pyplot as plt
from tabulate import tabulate

cle_api="i76sQnZ5PVPb3vayMHvN"
id_mp="mp-7988"
with MPRester(cle_api) as l:
    structure=l.get_structure_by_material_id(id_mp)
    f=CifWriter(structure)
    f.write_file('structure.cif')
    analyzer=SpacegroupAnalyzer(structure).get_primitive_standard_structure()

# %%
xrd = XRDCalculator(wavelength = 1.54060)
motif_xrd= xrd.get_pattern(analyzer,scaled=True)
i=0
j=1
while i<=2:
    print("pic de diffraction n°",j)
    print(motif_xrd.hkls[i][0]['hkl'])
    print("l'intensité vaut", motif_xrd.y[i], " 'mise à l'échelle: 100' ")
    print("2\u03B8(°) vaut", motif_xrd.x[i],"°")
    print("\n")
    j=j+1
    i=i+1
xrd.show_plot(analyzer)
# Out:
# pic de diffraction n° 1
# (1, 1, 1)
# l'intensité vaut 25.79998991921692  'mise à l'échelle: 100'
# 2θ(°) vaut 12.031118108737813 °
#
#
# pic de diffraction n° 2
# (2, 2, 2)
# l'intensité vaut 28.01836408927442  'mise à l'échelle: 100'
# 2θ(°) vaut 24.197479620975358 °
#
#
# pic de diffraction n° 3
# (1, 0, 0)
# l'intensité vaut 0.05567644783938104  'mise à l'échelle: 100'
# 2θ(°) vaut 24.434892017414324 °
